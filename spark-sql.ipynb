# %%
__author__ = 'Jimin.Zhou'
from pyspark import SparkContext
from pyspark.serializers import PickleSerializer
from pyspark import SparkConf,Row
from pyspark.sql import SQLContext
import logging
from logging.config import fileConfig
from datetime import *
import traceback
import ConfigParser
import io
import cPickle
import sys
import pymongo
import mysql.connector
from scipy.sparse import *
from sklearn.feature_extraction.text import CountVectorizer
from math import *
from numpy import *
import re
from itertools import chain
import pandas as pd
import re
from collections import defaultdict
import itertools
from scipy.cluster.hierarchy import *
import jieba
from scipy.sparse import csr_matrix
import time

# %%
def getFeatVec(newsID, feat):
    vec = []
    for ft in feat:
        cp = ft.split(',')
        if len(cp) > 1:
            first = cp[0].encode('utf-8')
            second = cp[1].encode('utf-8')
            if first.isdigit():
                vec.append((newsID, int(first), float(second)))
    return vec
def agg(wd, ar):
    arr = []
    for n in ar:
        for m in ar:
            if n[0]<m[0]:
                tt = n[1]*m[1]
                if tt>0.003:
                    arr.append(((n[0],m[0]),tt))
    return arr
def find(x):
    global unset
    p = x
    while (unset[p]>=0):
        p=unset[p]
    while (x!=p):
        t = unset[x]
        unset[x] = p
        x = t
    return x
def unionSet(x,y):
    global unset
    x = find(x)
    y = find(y)
    if (x == y):
        return
    if unset[x] < unset[y]:
        unset[x] = unset[x] + unset[y]
        unset[y] = x
    else:
        unset[y] = unset[y] + unset[x];
        unset[x] = y
import pymongo
import re

'''
Created on 2013-11-7

@author: guoxiong.yuan
'''


def mongo_find(col, query, projection=None, sort=None, limit=2147483647, batch_size=100):
    cursor = col.find(spec=query, fields=projection, sort=sort, limit=limit)
    if batch_size > 0:
        cursor.batch_size(batch_size)
    return cursor


def mongo_find_one(col, query, projection=None, sort=None):
    return col.find_one(spec_or_id=query, fields=projection, sort=sort)


def mongo_save(col, obj):
    col.save(obj);


def mongo_update(col, query, document, multi=False):
    if "_id" in query:
        col.update({"_id": query["_id"]}, document, multi=multi)
    else:
        col.update(query, document, multi=multi)


def mongo_remove(col, doc):
    if "_id" in doc:
        col.remove({"_id": doc["_id"]})
    else:
        col.remove(doc)


def translate_filename(filename):
    filename = re.sub(r'/|\\|\"|\<|>|\?|:', "-", filename)
    filename = re.sub(r'\s', "", filename)
    filename = filename.replace('*', u'＊')
    return filename

# %%
def getNews(stDate, edDate):
    global sqlContext
    pirNews = sqlContext.sql("SELECT * FROM news WHERE publishDate > '"+stDate+"' AND publishDate < '"+edDate+"'")
    return pirNews

# %%
def repartition(dataList,threashold):
    global cosineDist
    cc =cosineDist.todok()
    see = set(dataList)
    mat_dok = [elm for elm in cc.iteritems() if (elm[0][0] in see)|(elm[0][1] in see)]
    noZeroInd = [elm[0] for elm in mat_dok if elm[1]>threashold]
    return noZeroInd

# %%
def cluster(dataList):
    global cosineDist
    global newsCatRes
    global cateIndex
    distMat = cosineDist[dataList][:,dataList]
    ind = list(itertools.combinations(range(len(dataList)),2))
    distMat = 1.0- distMat.todense()
    distMat[distMat<0]=0.0
    distMatCon = [distMat[ii] for ii in ind]
    linkJ = average(distMatCon)
    clusterJ = fcluster(linkJ, 0.7, 'distance')
    cll = len(clusterJ)
    for ind in xrange(cll):
       # news_cls_res[dataList[ind]]=clusterJ[ind]*tol+indx
        newsCatRes[dataList[ind]]=cateIndex-1+clusterJ[ind]
    cateIndex = cateIndex+max(clusterJ)

# %%
def directCombine(dataList):
    global cateIndex
    ll = len(dataList)
    for ind in xrange(ll):
       # news_cls_res[dataList[ind]]=clusterJ[ind]*tol+indx
        newsCatRes[dataList[ind]]=cateIndex
    cateIndex = cateIndex+1

# %%
def maxDate(nws):
    return max([x.publishDate for x in nws])

# %%
def groupNewsRes(news, groupMap):
    if groupMap.has_key(news.newsID):
        return (groupMap[news.newsID], news)
    else:
        return (news.newsID, news)

# %%
def partition(dataList, c):
    global unset
    #group to partitions
    noZeroInd = repartition(dataList, c)
    indexMap = sorted(list(set(chain.from_iterable(noZeroInd))))
    filteredNum = len(indexMap)
    map2Index = dict(zip(indexMap,range(filteredNum)))
    unset = [-1]*filteredNum
    for elm in noZeroInd:
        if elm[0] < elm[1]:
            unionSet(map2Index[elm[0]], map2Index[elm[1]])
    nodeLocMap = {}
    for ind in range(filteredNum):
        nodeLocMap[indexMap[ind]] = find(ind)
    groupedDistMat = defaultdict(list)
    for key, value in sorted(nodeLocMap.iteritems()):
        groupedDistMat[value].append(key)
    return groupedDistMat

# %%
def triple2ParseMatrix(finalData):
    #get dist mat to driver and regularize
    DistTriple = finalData.filter(lambda (x,y):y>0.3).collect()
    DistI = [int(x) for ((x,y),z) in DistTriple]
    DistJ = [int(y) for ((x,y),z) in DistTriple]
    maxInd = max(DistI+DistJ)
    DistV = [z for ((x,y),z) in DistTriple]
    Dist = coo_matrix((DistV,(DistI,DistJ)),shape=(maxInd+1,maxInd+1))
    Dist = Dist.tocsr()
    return Dist

# %%
#incursive partitions
def incurCluster(dataList, c):
    groupedDistMat = partition(dataList, c)
    #cluster by partiotions
    cc = 0
    print len(groupedDistMat)
    for item in groupedDistMat.iteritems():
        dataList = item[1]
        #print len(dataList)
        if len(dataList) < 5:
            cc = cc + 1
            directCombine(dataList)
            continue
            
        if len(dataList) > 500:
            #print len(dataList)
            incurCluster(dataList, c+0.1)
        else:
            cluster(dataList)

# %%
def processPriodNews(pirNews):
    global cosineDist
    global newsCatRes
    global cateIndex
    global distList
    #get dist pair
    newsFtData = pirNews.flatMap(lambda news: getFeatVec(news.newsID, news.newsFeature))
    dataGroupped = newsFtData.filter(lambda (x,y,z):z>0.01).map(lambda (x,y,z):(y,(x,z))).groupByKey()
    finalData = dataGroupped.flatMap(lambda (x,y):agg(x,y)).reduceByKey(lambda x,y:x+y)
    #get parse matrix
    cosineDist = triple2ParseMatrix(finalData)
    distDok =cosineDist.todok().keys()
    #partition
    newsCatRes = {}
    distList = sorted(list(set(chain.from_iterable(distDok))))
    cateIndex = 0
    print str(time.localtime().tm_min) + "starting cluster , news news count:" + str(len(distList))
    incurCluster(distList,0.3)
    print str(time.localtime().tm_min) + "cluster end"
    catedNewsMat = defaultdict(list)
    for key, value in sorted(newsCatRes.iteritems()):
        catedNewsMat[value].append(key)
    #build news-clusterID map
    newsCateFinalRes = {}
    for gp,key in catedNewsMat.iteritems():
        minID = inf
        for item in key:
            if minID > item:
                minID = item
        for item in key:
            newsCateFinalRes[item]=minID
    #broadcast group res
    newsCateResRDD = sc.broadcast(newsCateFinalRes)
    #save result(groupID and news) in RDD
    catResAllRDD = pirNews.map(lambda nws: groupNewsRes(nws, newsCateResRDD.value))
    catedAllRDD = catResAllRDD.groupByKey()
    return catedAllRDD

# %%
def restart(curDate):
    print "restarting..."
    global sc
    global schemaNews
    global sqlContext
    global activeNewsRDD
    global conf
    dataTosave = activeNewsRDD.collect()
    output_file = open(curDate.strftime('%Y-%m-%d')+"_activeNewsRDD.pickle",'w')  
    cPickle.dump(dataTosave,output_file)
    output_file.close()
    sc.stop()
    sc = SparkContext(conf=conf)
    allFiles = sc.textFile('/dw/sparkteam/jimin.zhou/JLnewsFeature201409252/*')
    sqlContext = SQLContext(sc)
    parts = allFiles.map(lambda l: l.split("\t"))
    newsFeatures = parts.map(lambda p: {"publishDate": p[0], "newsID": long(p[1]), "newsFeature":p[2].strip().split(' ')})
    schemaNews = sqlContext.inferSchema(newsFeatures)
    schemaNews.registerAsTable("news")
    activeNewsRDD = sc.parallelize(dataTosave)

# %%
def saveToMongo(groupedAllRDD):
    global mongodb
    global mongo_base
    res = groupedAllRDD.collect()
    for elm in res:
        for news in elm[1]:
            mongo_save(mongodb[mongo_base].jl_news_cluster, {'_id':news.newsID,'pubT':news.publishDate, 'sid':int(elm[0])})

# %%
def processDayAcc(stDate, edDate):
    #get news active
    global activeNewsRDD
    curDate = stDate
    while curDate < edDate:
        if curDate.isoweekday()==7:
            restart(curDate)
        edDateTmp = curDate + timedelta(3)
        stDateStr = curDate.strftime('%Y-%m-%d')
        edDateStr = edDateTmp.strftime('%Y-%m-%d')
        print str(time.localtime().tm_min) + "start processing + " + stDateStr
        #cal active
        tempRDD = activeNewsRDD.filter(lambda x: x.publishDate < stDateStr)
        pirNews = getNews(stDateStr,edDateStr)
        pirNews = pirNews.union(tempRDD)
        groupedAllRDD = processPriodNews(pirNews)
        nextDate = curDate + timedelta(1)
        nextDateStr = nextDate.strftime('%Y-%m-%d')
        res = groupedAllRDD.map(lambda (x,y): (x,y,maxDate(y))).filter(lambda (x,y,z): z>nextDateStr)
        activeNewsRDD = res.flatMap(lambda (x,y,z):list(y))
        print str(time.localtime().tm_min) + " starting save to mongoDB"
        saveToMongo(groupedAllRDD)
        curDate = curDate + timedelta(1)

# %%
def processDayFirst7(stDate):
    #get news active
    global activeNewsRDD
    global pirNews
    edDateTmp = stDate + timedelta(3)
    stDateStr = stDate.strftime('%Y-%m-%d')
    edDateStr = edDateTmp.strftime('%Y-%m-%d')
    pirNews = getNews(stDateStr,edDateStr)
    groupedAllRDD = processPriodNews(pirNews)
    saveToMongo(groupedAllRDD)
    nextDate = stDate + timedelta(1)
    nextDateStr = nextDate.strftime('%Y-%m-%d')
    res = groupedAllRDD.map(lambda (x,y): (x,y,maxDate(y))).filter(lambda (x,y,z): z>nextDateStr)
    activeNewsRDD = res.flatMap(lambda (x,y,z):list(y))

# %%
def init():
    global sc
    global sqlContext
    global schemaNews
    global conf
    sc = SparkContext(conf=conf)
    allFiles = sc.textFile('/dw/sparkteam/jimin.zhou/JLnewsFeature201409252/*')
    sqlContext = SQLContext(sc)
    parts = allFiles.map(lambda l: l.split("\t"))
    newsFeatures = parts.map(lambda p: {"publishDate": p[0], "newsID": long(p[1]), "newsFeature":p[2].strip().split(' ')})
    schemaNews = sqlContext.inferSchema(newsFeatures)
    schemaNews.registerAsTable("news")

# %%
def restoreFromError(curDate, endDate):
    print "loading and restarting..."
    global sc
    global activeNewsRDD
    output_file = file(curDate.strftime('%Y-%m-%d')+"_activeNewsRDD.pickle")  
    dataTosave = cPickle.load(output_file)
    output_file.close()
    activeNewsRDD = sc.parallelize(dataTosave)
    processDayAcc(curDate, endDate)

# %%
def main__():
    #batch all
    global conf
    global mongodb
    global mongo_base
    mongo_url = "mongodb://app_mole_dev:SOh3TbYhxuLiW8@nosql05-dev.datayes.com/mole-dev"
    mongo_base = "mole-dev"
    mongodb = pymongo.MongoClient(mongo_url)
    conf = SparkConf()
    conf.setMaster("yarn-client").setAppName("hirachical_sql").set("spark.executor.instances", 9)
    init()
    #batch
    processDayFirst7(datetime(2010,1,1))
    processDayAcc(datetime(2010,1,2), datetime(2014,9,26))
    #restoreFromError(datetime(2013,11,17),datetime(2014,9,11))

# %%
main__()
# Out:
# 15starting cluster , news news count:20
# 7
# 15cluster end
# 16start processing + 2010-01-02
# 16starting cluster , news news count:1179
# 267
# 16cluster end
# 16 starting save to mongoDB
# restarting...
# 16start processing + 2010-01-03
# 17starting cluster , news news count:3048
# 526
# 146
# 18cluster end
# 18 starting save to mongoDB
# 18start processing + 2010-01-04
# 18starting cluster , news news count:5082
# 703
# 284
# 19cluster end
# 19 starting save to mongoDB
# 19start processing + 2010-01-05
# 20starting cluster , news news count:6358
# 768
# 370
# 21cluster end
# 21 starting save to mongoDB
# 23start processing + 2010-01-06
# 23starting cluster , news news count:6978
# 776
# 397
# 18
# 25cluster end
# 25 starting save to mongoDB
# 25start processing + 2010-01-07
# 26starting cluster , news news count:5757
# 712
# 252
# 27cluster end
# 27 starting save to mongoDB
# 27start processing + 2010-01-08
# 28starting cluster , news news count:3888
# 496
# 134
# 29cluster end
# 29 starting save to mongoDB
# 29start processing + 2010-01-09
# 29starting cluster , news news count:2241
# 395
# 46
# 29cluster end
# 29 starting save to mongoDB
# restarting...
# 30start processing + 2010-01-10
# 30starting cluster , news news count:3525
# 551
# 130
# 31cluster end
# 31 starting save to mongoDB
# 31start processing + 2010-01-11
# 31starting cluster , news news count:5477
# 745
# 254
# 65
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2010-01-12
# 33starting cluster , news news count:6227
# 755
# 324
# 62
# 35cluster end
# 35 starting save to mongoDB
# 35start processing + 2010-01-13
# 35starting cluster , news news count:6654
# 723
# 365
# 63
# 12
# 37cluster end
# 37 starting save to mongoDB
# 38start processing + 2010-01-14
# 38starting cluster , news news count:5415
# 600
# 283
# 16
# 39cluster end
# 39 starting save to mongoDB
# 40start processing + 2010-01-15
# 40starting cluster , news news count:3831
# 485
# 143
# 10
# 41cluster end
# 41 starting save to mongoDB
# 42start processing + 2010-01-16
# 42starting cluster , news news count:2330
# 383
# 76
# 43cluster end
# 43 starting save to mongoDB
# restarting...
# 45start processing + 2010-01-17
# 46starting cluster , news news count:3764
# 555
# 175
# 47cluster end
# 47 starting save to mongoDB
# 47start processing + 2010-01-18
# 48starting cluster , news news count:5643
# 693
# 327
# 49cluster end
# 49 starting save to mongoDB
# 49start processing + 2010-01-19
# 50starting cluster , news news count:6581
# 755
# 356
# 68
# 52cluster end
# 52 starting save to mongoDB
# 53start processing + 2010-01-20
# 53starting cluster , news news count:6946
# 735
# 360
# 81
# 55cluster end
# 55 starting save to mongoDB
# 55start processing + 2010-01-21
# 55starting cluster , news news count:5790
# 697
# 257
# 61
# 57cluster end
# 57 starting save to mongoDB
# 57start processing + 2010-01-22
# 57starting cluster , news news count:3961
# 524
# 117
# 24
# 58cluster end
# 58 starting save to mongoDB
# 59start processing + 2010-01-23
# 59starting cluster , news news count:2132
# 371
# 71
# 0cluster end
# 0 starting save to mongoDB
# restarting...
# 0start processing + 2010-01-24
# 0starting cluster , news news count:3562
# 549
# 143
# 1cluster end
# 1 starting save to mongoDB
# 2start processing + 2010-01-25
# 2starting cluster , news news count:5601
# 762
# 274
# 3cluster end
# 3 starting save to mongoDB
# 3start processing + 2010-01-26
# 4starting cluster , news news count:6610
# 808
# 357
# 80
# 5cluster end
# 5 starting save to mongoDB
# 6start processing + 2010-01-27
# 6starting cluster , news news count:7066
# 798
# 379
# 110
# 6
# 9cluster end
# 9 starting save to mongoDB
# 11start processing + 2010-01-28
# 11starting cluster , news news count:5807
# 681
# 279
# 14cluster end
# 14 starting save to mongoDB
# 14start processing + 2010-01-29
# 14starting cluster , news news count:4004
# 521
# 152
# 17cluster end
# 17 starting save to mongoDB
# 17start processing + 2010-01-30
# 17starting cluster , news news count:2403
# 384
# 91
# 18cluster end
# 18 starting save to mongoDB
# restarting...
# 18start processing + 2010-01-31
# 18starting cluster , news news count:3692
# 518
# 173
# 19cluster end
# 19 starting save to mongoDB
# 19start processing + 2010-02-01
# 20starting cluster , news news count:5549
# 697
# 274
# 21cluster end
# 21 starting save to mongoDB
# 21start processing + 2010-02-02
# 21starting cluster , news news count:6328
# 803
# 309
# 88
# 23cluster end
# 23 starting save to mongoDB
# 23start processing + 2010-02-03
# 24starting cluster , news news count:6557
# 827
# 311
# 7
# 25cluster end
# 25 starting save to mongoDB
# 26start processing + 2010-02-04
# 26starting cluster , news news count:5502
# 722
# 210
# 7
# 27cluster end
# 27 starting save to mongoDB
# 28start processing + 2010-02-05
# 28starting cluster , news news count:3809
# 502
# 121
# 5
# 29cluster end
# 29 starting save to mongoDB
# 29start processing + 2010-02-06
# 29starting cluster , news news count:2216
# 336
# 77
# 30cluster end
# 30 starting save to mongoDB
# restarting...
# 30start processing + 2010-02-07
# 31starting cluster , news news count:3596
# 485
# 157
# 31cluster end
# 31 starting save to mongoDB
# 32start processing + 2010-02-08
# 32starting cluster , news news count:5443
# 646
# 263
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2010-02-09
# 34starting cluster , news news count:6287
# 694
# 338
# 68
# 29
# 35cluster end
# 35 starting save to mongoDB
# 35start processing + 2010-02-10
# 36starting cluster , news news count:6242
# 667
# 281
# 63
# 20
# 37cluster end
# 37 starting save to mongoDB
# 38start processing + 2010-02-11
# 38starting cluster , news news count:4460
# 531
# 161
# 13
# 39cluster end
# 39 starting save to mongoDB
# 39start processing + 2010-02-12
# 39starting cluster , news news count:2765
# 313
# 54
# 8
# 40cluster end
# 40 starting save to mongoDB
# 40start processing + 2010-02-13
# 41starting cluster , news news count:146
# 8
# 41cluster end
# 41 starting save to mongoDB
# restarting...
# 41start processing + 2010-02-14
# 41starting cluster , news news count:148
# 7
# 41cluster end
# 41 starting save to mongoDB
# 41start processing + 2010-02-15
# 42starting cluster , news news count:105
# 13
# 42cluster end
# 42 starting save to mongoDB
# 42start processing + 2010-02-16
# 42starting cluster , news news count:172
# 28
# 42cluster end
# 42 starting save to mongoDB
# 42start processing + 2010-02-17
# 42starting cluster , news news count:244
# 37
# 42cluster end
# 42 starting save to mongoDB
# 43start processing + 2010-02-18
# 43starting cluster , news news count:233
# 36
# 43cluster end
# 43 starting save to mongoDB
# 43start processing + 2010-02-19
# 43starting cluster , news news count:191
# 33
# 43cluster end
# 43 starting save to mongoDB
# 43start processing + 2010-02-20
# 44starting cluster , news news count:1165
# 177
# 47
# 44cluster end
# 44 starting save to mongoDB
# restarting...
# 44start processing + 2010-02-21
# 44starting cluster , news news count:2882
# 387
# 116
# 58
# 45cluster end
# 45 starting save to mongoDB
# 45start processing + 2010-02-22
# 46starting cluster , news news count:4702
# 540
# 243
# 93
# 47cluster end
# 47 starting save to mongoDB
# 47start processing + 2010-02-23
# 47starting cluster , news news count:5759
# 616
# 303
# 94
# 50cluster end
# 50 starting save to mongoDB
# 50start processing + 2010-02-24
# 51starting cluster , news news count:6323
# 628
# 355
# 107
# 53cluster end
# 53 starting save to mongoDB
# 53start processing + 2010-02-25
# 53starting cluster , news news count:5279
# 577
# 247
# 82
# 55cluster end
# 55 starting save to mongoDB
# 55start processing + 2010-02-26
# 55starting cluster , news news count:3703
# 431
# 135
# 45
# 56cluster end
# 56 starting save to mongoDB
# 56start processing + 2010-02-27
# 57starting cluster , news news count:2671
# 377
# 98
# 57cluster end
# 57 starting save to mongoDB
# restarting...
# 58start processing + 2010-02-28
# 58starting cluster , news news count:4262
# 491
# 223
# 59cluster end
# 59 starting save to mongoDB
# 59start processing + 2010-03-01
# 59starting cluster , news news count:6280
# 648
# 344
# 116
# 1cluster end
# 1 starting save to mongoDB
# 1start processing + 2010-03-02
# 1starting cluster , news news count:7123
# 715
# 395
# 142
# 3cluster end
# 3 starting save to mongoDB
# 3start processing + 2010-03-03
# 4starting cluster , news news count:7314
# 715
# 11
# 332
# 175
# 5cluster end
# 5 starting save to mongoDB
# 6start processing + 2010-03-04
# 6starting cluster , news news count:6079
# 611
# 5
# 233
# 145
# 7cluster end
# 7 starting save to mongoDB
# 8start processing + 2010-03-05
# 8starting cluster , news news count:4080
# 433
# 3
# 128
# 9cluster end
# 9 starting save to mongoDB
# 9start processing + 2010-03-06
# 9starting cluster , news news count:2428
# 324
# 94
# 10cluster end
# 10 starting save to mongoDB
# restarting...
# 11start processing + 2010-03-07
# 11starting cluster , news news count:3637
# 523
# 153
# 12cluster end
# 12 starting save to mongoDB
# 12start processing + 2010-03-08
# 13starting cluster , news news count:5572
# 690
# 275
# 14cluster end
# 14 starting save to mongoDB
# 14start processing + 2010-03-09
# 15starting cluster , news news count:6559
# 713
# 314
# 44
# 16cluster end
# 16 starting save to mongoDB
# 16start processing + 2010-03-10
# 17starting cluster , news news count:6953
# 700
# 318
# 57
# 18cluster end
# 18 starting save to mongoDB
# 19start processing + 2010-03-11
# 19starting cluster , news news count:5788
# 585
# 261
# 20cluster end
# 20 starting save to mongoDB
# 21start processing + 2010-03-12
# 21starting cluster , news news count:3960
# 452
# 123
# 16
# 22cluster end
# 22 starting save to mongoDB
# 22start processing + 2010-03-13
# 23starting cluster , news news count:2402
# 310
# 78
# 23cluster end
# 23 starting save to mongoDB
# restarting...
# 24start processing + 2010-03-14
# 24starting cluster , news news count:3703
# 449
# 130
# 25cluster end
# 25 starting save to mongoDB
# 25start processing + 2010-03-15
# 25starting cluster , news news count:5613
# 629
# 257
# 81
# 26cluster end
# 26 starting save to mongoDB
# 27start processing + 2010-03-16
# 27starting cluster , news news count:6670
# 713
# 320
# 130
# 29cluster end
# 29 starting save to mongoDB
# 29start processing + 2010-03-17
# 29starting cluster , news news count:7140
# 701
# 341
# 125
# 31cluster end
# 31 starting save to mongoDB
# 31start processing + 2010-03-18
# 31starting cluster , news news count:5996
# 606
# 241
# 81
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2010-03-19
# 34starting cluster , news news count:4300
# 448
# 122
# 31
# 35cluster end
# 35 starting save to mongoDB
# 35start processing + 2010-03-20
# 35starting cluster , news news count:2634
# 326
# 58
# 36cluster end
# 36 starting save to mongoDB
# restarting...
# 36start processing + 2010-03-21
# 36starting cluster , news news count:4130
# 499
# 174
# 37cluster end
# 37 starting save to mongoDB
# 37start processing + 2010-03-22
# 37starting cluster , news news count:6081
# 668
# 284
# 50
# 39cluster end
# 39 starting save to mongoDB
# 39start processing + 2010-03-23
# 39starting cluster , news news count:7065
# 743
# 333
# 60
# 41cluster end
# 41 starting save to mongoDB
# 41start processing + 2010-03-24
# 41starting cluster , news news count:7466
# 734
# 355
# 70
# 43cluster end
# 43 starting save to mongoDB
# 43start processing + 2010-03-25
# 43starting cluster , news news count:6351
# 652
# 274
# 64
# 45cluster end
# 45 starting save to mongoDB
# 45start processing + 2010-03-26
# 46starting cluster , news news count:4650
# 494
# 157
# 28
# 47cluster end
# 47 starting save to mongoDB
# 47start processing + 2010-03-27
# 47starting cluster , news news count:3044
# 367
# 93
# 11
# 48cluster end
# 48 starting save to mongoDB
# restarting...
# 48start processing + 2010-03-28
# 48starting cluster , news news count:4484
# 528
# 157
# 10
# 49cluster end
# 49 starting save to mongoDB
# 49start processing + 2010-03-29
# 50starting cluster , news news count:6677
# 704
# 279
# 20
# 33
# 51cluster end
# 51 starting save to mongoDB
# 51start processing + 2010-03-30
# 52starting cluster , news news count:7428
# 776
# 371
# 32
# 32
# 53cluster end
# 53 starting save to mongoDB
# 53start processing + 2010-03-31
# 54starting cluster , news news count:7475
# 742
# 377
# 66
# 56cluster end
# 56 starting save to mongoDB
# 56start processing + 2010-04-01
# 56starting cluster , news news count:5949
# 651
# 232
# 46
# 58cluster end
# 58 starting save to mongoDB
# 58start processing + 2010-04-02
# 58starting cluster , news news count:3987
# 446
# 109
# 19
# 59cluster end
# 59 starting save to mongoDB
# 59start processing + 2010-04-03
# 59starting cluster , news news count:1434
# 174
# 7
# 5
# 0cluster end
# 0 starting save to mongoDB
# restarting...
# 0start processing + 2010-04-04
# 0starting cluster , news news count:1290
# 209
# 1cluster end
# 1 starting save to mongoDB
# 1start processing + 2010-04-05
# 1starting cluster , news news count:2986
# 439
# 110
# 2cluster end
# 2 starting save to mongoDB
# 2start processing + 2010-04-06
# 2starting cluster , news news count:4850
# 661
# 225
# 46
# 3cluster end
# 3 starting save to mongoDB
# 4start processing + 2010-04-07
# 4starting cluster , news news count:6196
# 774
# 270
# 46
# 5cluster end
# 5 starting save to mongoDB
# 6start processing + 2010-04-08
# 6starting cluster , news news count:5565
# 707
# 203
# 46
# 7cluster end
# 7 starting save to mongoDB
# 8start processing + 2010-04-09
# 8starting cluster , news news count:3937
# 510
# 107
# 27
# 9cluster end
# 9 starting save to mongoDB
# 9start processing + 2010-04-10
# 9starting cluster , news news count:2938
# 408
# 73
# 38
# 10cluster end
# 10 starting save to mongoDB
# restarting...
# 11start processing + 2010-04-11
# 11starting cluster , news news count:4282
# 570
# 163
# 58
# 12cluster end
# 12 starting save to mongoDB
# 12start processing + 2010-04-12
# 12starting cluster , news news count:6309
# 735
# 269
# 97
# 14cluster end
# 14 starting save to mongoDB
# 14start processing + 2010-04-13
# 14starting cluster , news news count:7092
# 772
# 343
# 74
# 16cluster end
# 16 starting save to mongoDB
# 16start processing + 2010-04-14
# 16starting cluster , news news count:7471
# 749
# 333
# 102
# 18cluster end
# 18 starting save to mongoDB
# 18start processing + 2010-04-15
# 18starting cluster , news news count:6300
# 599
# 274
# 35
# 20cluster end
# 20 starting save to mongoDB
# 20start processing + 2010-04-16
# 20starting cluster , news news count:4469
# 450
# 135
# 18
# 21cluster end
# 21 starting save to mongoDB
# 22start processing + 2010-04-17
# 22starting cluster , news news count:2855
# 376
# 56
# 22cluster end
# 22 starting save to mongoDB
# restarting...
# 23start processing + 2010-04-18
# 23starting cluster , news news count:4231
# 481
# 171
# 39
# 24cluster end
# 24 starting save to mongoDB
# 24start processing + 2010-04-19
# 24starting cluster , news news count:6233
# 647
# 306
# 56
# 25cluster end
# 25 starting save to mongoDB
# 26start processing + 2010-04-20
# 26starting cluster , news news count:7232
# 721
# 358
# 84
# 27cluster end
# 27 starting save to mongoDB
# 28start processing + 2010-04-21
# 28starting cluster , news news count:7867
# 789
# 341
# 139
# 30cluster end
# 30 starting save to mongoDB
# 30start processing + 2010-04-22
# 31starting cluster , news news count:6796
# 711
# 289
# 100
# 32cluster end
# 32 starting save to mongoDB
# 32start processing + 2010-04-23
# 33starting cluster , news news count:4752
# 540
# 161
# 43
# 34cluster end
# 34 starting save to mongoDB
# 34start processing + 2010-04-24
# 34starting cluster , news news count:3183
# 388
# 95
# 35cluster end
# 35 starting save to mongoDB
# restarting...
# 35start processing + 2010-04-25
# 36starting cluster , news news count:4511
# 586
# 170
# 36cluster end
# 36 starting save to mongoDB
# 37start processing + 2010-04-26
# 37starting cluster , news news count:6752
# 784
# 297
# 81
# 18
# 38cluster end
# 38 starting save to mongoDB
# 39start processing + 2010-04-27
# 39starting cluster , news news count:7931
# 830
# 394
# 146
# 21
# 40cluster end
# 40 starting save to mongoDB
# 41start processing + 2010-04-28
# 41starting cluster , news news count:8385
# 788
# 405
# 173
# 26
# 25
# 43cluster end
# 43 starting save to mongoDB
# 43start processing + 2010-04-29
# 43starting cluster , news news count:6434
# 656
# 278
# 106
# 23
# 45cluster end
# 45 starting save to mongoDB
# 45start processing + 2010-04-30
# 45starting cluster , news news count:4191
# 452
# 122
# 14
# 35
# 46cluster end
# 46 starting save to mongoDB
# 46start processing + 2010-05-01
# 47starting cluster , news news count:341
# 62
# 47cluster end
# 47 starting save to mongoDB
# restarting...
# 47start processing + 2010-05-02
# 47starting cluster , news news count:1434
# 286
# 47cluster end
# 47 starting save to mongoDB
# 48start processing + 2010-05-03
# 48starting cluster , news news count:2936
# 528
# 90
# 48cluster end
# 48 starting save to mongoDB
# 49start processing + 2010-05-04
# 49starting cluster , news news count:4631
# 681
# 196
# 50cluster end
# 50 starting save to mongoDB
# 51start processing + 2010-05-05
# 51starting cluster , news news count:5516
# 723
# 242
# 52cluster end
# 52 starting save to mongoDB
# 53start processing + 2010-05-06
# 53starting cluster , news news count:4910
# 657
# 181
# 54cluster end
# 54 starting save to mongoDB
# 54start processing + 2010-05-07
# 54starting cluster , news news count:3455
# 505
# 79
# 55cluster end
# 55 starting save to mongoDB
# 56start processing + 2010-05-08
# 56starting cluster , news news count:2298
# 430
# 56cluster end
# 56 starting save to mongoDB
# restarting...
# 57start processing + 2010-05-09
# 57starting cluster , news news count:3739
# 555
# 154
# 58cluster end
# 58 starting save to mongoDB
# 58start processing + 2010-05-10
# 58starting cluster , news news count:5620
# 731
# 261
# 0cluster end
# 0 starting save to mongoDB
# 0start processing + 2010-05-11
# 0starting cluster , news news count:6503
# 752
# 340
# 2cluster end
# 2 starting save to mongoDB
# 2start processing + 2010-05-12
# 2starting cluster , news news count:6840
# 792
# 323
# 4cluster end
# 4 starting save to mongoDB
# 4start processing + 2010-05-13
# 4starting cluster , news news count:5663
# 724
# 213
# 20
# 6cluster end
# 6 starting save to mongoDB
# 6start processing + 2010-05-14
# 6starting cluster , news news count:3910
# 528
# 106
# 13
# 7cluster end
# 7 starting save to mongoDB
# 8start processing + 2010-05-15
# 9starting cluster , news news count:2488
# 362
# 77
# 9cluster end
# 9 starting save to mongoDB
# restarting...
# 9start processing + 2010-05-16
# 10starting cluster , news news count:3537
# 491
# 137
# 10cluster end
# 10 starting save to mongoDB
# 11start processing + 2010-05-17
# 11starting cluster , news news count:5433
# 704
# 236
# 45
# 12cluster end
# 12 starting save to mongoDB
# 12start processing + 2010-05-18
# 13starting cluster , news news count:6303
# 780
# 268
# 16
# 14cluster end
# 14 starting save to mongoDB
# 14start processing + 2010-05-19
# 15starting cluster , news news count:6712
# 792
# 284
# 9
# 16cluster end
# 16 starting save to mongoDB
# 16start processing + 2010-05-20
# 17starting cluster , news news count:5549
# 708
# 195
# 18cluster end
# 18 starting save to mongoDB
# 18start processing + 2010-05-21
# 18starting cluster , news news count:3868
# 508
# 112
# 19cluster end
# 19 starting save to mongoDB
# 20start processing + 2010-05-22
# 20starting cluster , news news count:2383
# 387
# 52
# 20cluster end
# 20 starting save to mongoDB
# restarting...
# 21start processing + 2010-05-23
# 21starting cluster , news news count:3591
# 509
# 108
# 22cluster end
# 22 starting save to mongoDB
# 22start processing + 2010-05-24
# 22starting cluster , news news count:5360
# 689
# 232
# 23cluster end
# 23 starting save to mongoDB
# 24start processing + 2010-05-25
# 24starting cluster , news news count:6162
# 795
# 261
# 25cluster end
# 25 starting save to mongoDB
# 25start processing + 2010-05-26
# 26starting cluster , news news count:6458
# 742
# 319
# 13
# 27cluster end
# 27 starting save to mongoDB
# 27start processing + 2010-05-27
# 28starting cluster , news news count:5459
# 634
# 237
# 29cluster end
# 29 starting save to mongoDB
# 29start processing + 2010-05-28
# 30starting cluster , news news count:3731
# 432
# 106
# 30cluster end
# 30 starting save to mongoDB
# 31start processing + 2010-05-29
# 31starting cluster , news news count:2215
# 354
# 31cluster end
# 31 starting save to mongoDB
# restarting...
# 32start processing + 2010-05-30
# 32starting cluster , news news count:3514
# 537
# 117
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2010-05-31
# 33starting cluster , news news count:5341
# 689
# 257
# 35cluster end
# 35 starting save to mongoDB
# 35start processing + 2010-06-01
# 35starting cluster , news news count:6049
# 753
# 282
# 37cluster end
# 37 starting save to mongoDB
# 37start processing + 2010-06-02
# 37starting cluster , news news count:6350
# 776
# 300
# 10
# 39cluster end
# 39 starting save to mongoDB
# 39start processing + 2010-06-03
# 39starting cluster , news news count:5159
# 671
# 200
# 41cluster end
# 41 starting save to mongoDB
# 41start processing + 2010-06-04
# 41starting cluster , news news count:3492
# 488
# 80
# 42cluster end
# 42 starting save to mongoDB
# 42start processing + 2010-06-05
# 42starting cluster , news news count:2145
# 361
# 43cluster end
# 43 starting save to mongoDB
# restarting...
# 43start processing + 2010-06-06
# 44starting cluster , news news count:3432
# 500
# 129
# 44cluster end
# 44 starting save to mongoDB
# 45start processing + 2010-06-07
# 45starting cluster , news news count:5207
# 640
# 237
# 46cluster end
# 46 starting save to mongoDB
# 46start processing + 2010-06-08
# 47starting cluster , news news count:5996
# 712
# 293
# 56
# 48cluster end
# 48 starting save to mongoDB
# 50start processing + 2010-06-09
# 50starting cluster , news news count:6333
# 695
# 292
# 69
# 8
# 52cluster end
# 52 starting save to mongoDB
# 52start processing + 2010-06-10
# 52starting cluster , news news count:5242
# 607
# 238
# 54cluster end
# 54 starting save to mongoDB
# 54start processing + 2010-06-11
# 54starting cluster , news news count:3597
# 432
# 119
# 55cluster end
# 55 starting save to mongoDB
# 55start processing + 2010-06-12
# 55starting cluster , news news count:879
# 160
# 56cluster end
# 56 starting save to mongoDB
# restarting...
# 56start processing + 2010-06-13
# 56starting cluster , news news count:229
# 15
# 56cluster end
# 56 starting save to mongoDB
# 56start processing + 2010-06-14
# 57starting cluster , news news count:229
# 12
# 57cluster end
# 57 starting save to mongoDB
# 57start processing + 2010-06-15
# 57starting cluster , news news count:1228
# 214
# 57cluster end
# 57 starting save to mongoDB
# 57start processing + 2010-06-16
# 58starting cluster , news news count:2863
# 461
# 61
# 58cluster end
# 58 starting save to mongoDB
# 59start processing + 2010-06-17
# 59starting cluster , news news count:3280
# 534
# 100
# 59cluster end
# 59 starting save to mongoDB
# 0start processing + 2010-06-18
# 0starting cluster , news news count:2627
# 476
# 0cluster end
# 0 starting save to mongoDB
# 1start processing + 2010-06-19
# 1starting cluster , news news count:1958
# 358
# 1cluster end
# 1 starting save to mongoDB
# restarting...
# 2start processing + 2010-06-20
# 2starting cluster , news news count:3263
# 538
# 113
# 3cluster end
# 3 starting save to mongoDB
# 3start processing + 2010-06-21
# 3starting cluster , news news count:4977
# 709
# 220
# 4cluster end
# 4 starting save to mongoDB
# 5start processing + 2010-06-22
# 5starting cluster , news news count:5744
# 755
# 270
# 70
# 6cluster end
# 6 starting save to mongoDB
# 7start processing + 2010-06-23
# 7starting cluster , news news count:6031
# 744
# 252
# 75
# 9cluster end
# 9 starting save to mongoDB
# 11start processing + 2010-06-24
# 11starting cluster , news news count:5039
# 646
# 174
# 12cluster end
# 12 starting save to mongoDB
# 13start processing + 2010-06-25
# 13starting cluster , news news count:3488
# 484
# 62
# 14cluster end
# 14 starting save to mongoDB
# 14start processing + 2010-06-26
# 14starting cluster , news news count:2141
# 340
# 51
# 15cluster end
# 15 starting save to mongoDB
# restarting...
# 15start processing + 2010-06-27
# 15starting cluster , news news count:3332
# 528
# 65
# 16cluster end
# 16 starting save to mongoDB
# 16start processing + 2010-06-28
# 16starting cluster , news news count:5046
# 696
# 210
# 18cluster end
# 18 starting save to mongoDB
# 18start processing + 2010-06-29
# 18starting cluster , news news count:5662
# 737
# 278
# 19cluster end
# 19 starting save to mongoDB
# 20start processing + 2010-06-30
# 20starting cluster , news news count:5986
# 740
# 275
# 21cluster end
# 21 starting save to mongoDB
# 22start processing + 2010-07-01
# 22starting cluster , news news count:5124
# 667
# 184
# 23cluster end
# 23 starting save to mongoDB
# 23start processing + 2010-07-02
# 24starting cluster , news news count:3608
# 494
# 52
# 24cluster end
# 24 starting save to mongoDB
# 25start processing + 2010-07-03
# 25starting cluster , news news count:2213
# 387
# 53
# 26cluster end
# 26 starting save to mongoDB
# restarting...
# 26start processing + 2010-07-04
# 26starting cluster , news news count:3445
# 551
# 86
# 27cluster end
# 27 starting save to mongoDB
# 29start processing + 2010-07-05
# 30starting cluster , news news count:5077
# 707
# 166
# 31cluster end
# 31 starting save to mongoDB
# 31start processing + 2010-07-06
# 31starting cluster , news news count:5802
# 779
# 216
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2010-07-07
# 33starting cluster , news news count:6126
# 807
# 218
# 35cluster end
# 35 starting save to mongoDB
# 35start processing + 2010-07-08
# 35starting cluster , news news count:5110
# 713
# 176
# 37cluster end
# 37 starting save to mongoDB
# 37start processing + 2010-07-09
# 37starting cluster , news news count:3615
# 531
# 87
# 38cluster end
# 38 starting save to mongoDB
# 38start processing + 2010-07-10
# 38starting cluster , news news count:2221
# 367
# 39cluster end
# 39 starting save to mongoDB
# restarting...
# 39start processing + 2010-07-11
# 40starting cluster , news news count:3385
# 488
# 93
# 40cluster end
# 40 starting save to mongoDB
# 41start processing + 2010-07-12
# 41starting cluster , news news count:5221
# 671
# 244
# 42cluster end
# 42 starting save to mongoDB
# 42start processing + 2010-07-13
# 42starting cluster , news news count:5973
# 707
# 281
# 56
# 44cluster end
# 44 starting save to mongoDB
# 44start processing + 2010-07-14
# 44starting cluster , news news count:6342
# 706
# 273
# 56
# 46cluster end
# 46 starting save to mongoDB
# 46start processing + 2010-07-15
# 46starting cluster , news news count:5320
# 596
# 188
# 48cluster end
# 48 starting save to mongoDB
# 48start processing + 2010-07-16
# 48starting cluster , news news count:3638
# 405
# 110
# 49cluster end
# 49 starting save to mongoDB
# 49start processing + 2010-07-17
# 50starting cluster , news news count:2110
# 314
# 50cluster end
# 50 starting save to mongoDB
# restarting...
# 50start processing + 2010-07-18
# 51starting cluster , news news count:3316
# 485
# 139
# 51cluster end
# 51 starting save to mongoDB
# 52start processing + 2010-07-19
# 52starting cluster , news news count:4946
# 620
# 225
# 33
# 53cluster end
# 53 starting save to mongoDB
# 53start processing + 2010-07-20
# 54starting cluster , news news count:5664
# 696
# 241
# 32
# 55cluster end
# 55 starting save to mongoDB
# 55start processing + 2010-07-21
# 56starting cluster , news news count:5991
# 682
# 245
# 57cluster end
# 57 starting save to mongoDB
# 57start processing + 2010-07-22
# 58starting cluster , news news count:4989
# 625
# 190
# 59cluster end
# 59 starting save to mongoDB
# 59start processing + 2010-07-23
# 59starting cluster , news news count:3476
# 474
# 51
# 0cluster end
# 0 starting save to mongoDB
# 1start processing + 2010-07-24
# 1starting cluster , news news count:2143
# 332
# 66
# 1cluster end
# 1 starting save to mongoDB
# restarting...
# 2start processing + 2010-07-25
# 2starting cluster , news news count:3440
# 521
# 135
# 3cluster end
# 3 starting save to mongoDB
# 3start processing + 2010-07-26
# 3starting cluster , news news count:5226
# 737
# 216
# 5cluster end
# 5 starting save to mongoDB
# 5start processing + 2010-07-27
# 5starting cluster , news news count:6090
# 810
# 274
# 7cluster end
# 7 starting save to mongoDB
# 7start processing + 2010-07-28
# 7starting cluster , news news count:6658
# 803
# 267
# 9cluster end
# 9 starting save to mongoDB
# 9start processing + 2010-07-29
# 10starting cluster , news news count:5634
# 680
# 220
# 11cluster end
# 11 starting save to mongoDB
# 11start processing + 2010-07-30
# 12starting cluster , news news count:3957
# 507
# 115
# 13cluster end
# 13 starting save to mongoDB
# 13start processing + 2010-07-31
# 13starting cluster , news news count:2336
# 351
# 52
# 14cluster end
# 14 starting save to mongoDB
# restarting...
# 14start processing + 2010-08-01
# 14starting cluster , news news count:3404
# 511
# 103
# 15cluster end
# 15 starting save to mongoDB
# 15start processing + 2010-08-02
# 16starting cluster , news news count:4982
# 694
# 191
# 17cluster end
# 17 starting save to mongoDB
# 17start processing + 2010-08-03
# 17starting cluster , news news count:5519
# 755
# 205
# 19cluster end
# 19 starting save to mongoDB
# 19start processing + 2010-08-04
# 19starting cluster , news news count:5798
# 727
# 233
# 21cluster end
# 21 starting save to mongoDB
# 21start processing + 2010-08-05
# 21starting cluster , news news count:4732
# 633
# 157
# 23cluster end
# 23 starting save to mongoDB
# 23start processing + 2010-08-06
# 23starting cluster , news news count:3305
# 445
# 79
# 24cluster end
# 24 starting save to mongoDB
# 24start processing + 2010-08-07
# 24starting cluster , news news count:2231
# 338
# 25cluster end
# 25 starting save to mongoDB
# restarting...
# 25start processing + 2010-08-08
# 25starting cluster , news news count:3563
# 495
# 94
# 26cluster end
# 26 starting save to mongoDB
# 26start processing + 2010-08-09
# 27starting cluster , news news count:5412
# 625
# 233
# 28cluster end
# 28 starting save to mongoDB
# 28start processing + 2010-08-10
# 28starting cluster , news news count:6276
# 698
# 288
# 63
# 30cluster end
# 30 starting save to mongoDB
# 30start processing + 2010-08-11
# 30starting cluster , news news count:6416
# 680
# 256
# 95
# 32cluster end
# 32 starting save to mongoDB
# 32start processing + 2010-08-12
# 33starting cluster , news news count:5140
# 598
# 164
# 63
# 34cluster end
# 34 starting save to mongoDB
# 34start processing + 2010-08-13
# 34starting cluster , news news count:3392
# 433
# 61
# 35cluster end
# 35 starting save to mongoDB
# 35start processing + 2010-08-14
# 36starting cluster , news news count:2141
# 351
# 36cluster end
# 36 starting save to mongoDB
# restarting...
# 37start processing + 2010-08-15
# 37starting cluster , news news count:3576
# 524
# 112
# 38cluster end
# 38 starting save to mongoDB
# 38start processing + 2010-08-16
# 39starting cluster , news news count:5336
# 675
# 254
# 40cluster end
# 40 starting save to mongoDB
# 40start processing + 2010-08-17
# 41starting cluster , news news count:6307
# 737
# 312
# 42cluster end
# 42 starting save to mongoDB
# 42start processing + 2010-08-18
# 42starting cluster , news news count:6697
# 748
# 331
# 14
# 61
# 44cluster end
# 44 starting save to mongoDB
# 44start processing + 2010-08-19
# 45starting cluster , news news count:5532
# 694
# 208
# 45
# 46cluster end
# 46 starting save to mongoDB
# 46start processing + 2010-08-20
# 47starting cluster , news news count:3857
# 516
# 97
# 48cluster end
# 48 starting save to mongoDB
# 48start processing + 2010-08-21
# 48starting cluster , news news count:2563
# 384
# 28
# 49cluster end
# 49 starting save to mongoDB
# restarting...
# 49start processing + 2010-08-22
# 49starting cluster , news news count:3901
# 532
# 114
# 50cluster end
# 50 starting save to mongoDB
# 50start processing + 2010-08-23
# 51starting cluster , news news count:5862
# 747
# 243
# 57
# 52cluster end
# 52 starting save to mongoDB
# 52start processing + 2010-08-24
# 53starting cluster , news news count:6803
# 806
# 280
# 71
# 54cluster end
# 54 starting save to mongoDB
# 55start processing + 2010-08-25
# 55starting cluster , news news count:7299
# 831
# 303
# 19
# 74
# 57cluster end
# 57 starting save to mongoDB
# 57start processing + 2010-08-26
# 57starting cluster , news news count:5993
# 704
# 229
# 53
# 59cluster end
# 59 starting save to mongoDB
# 59start processing + 2010-08-27
# 59starting cluster , news news count:4199
# 518
# 114
# 0cluster end
# 0 starting save to mongoDB
# 1start processing + 2010-08-28
# 1starting cluster , news news count:2837
# 394
# 63
# 1cluster end
# 1 starting save to mongoDB
# restarting...
# 2start processing + 2010-08-29
# 2starting cluster , news news count:4258
# 554
# 177
# 3cluster end
# 3 starting save to mongoDB
# 3start processing + 2010-08-30
# 3starting cluster , news news count:5982
# 713
# 288
# 67
# 5cluster end
# 5 starting save to mongoDB
# 5start processing + 2010-08-31
# 5starting cluster , news news count:6428
# 765
# 299
# 41
# 6cluster end
# 6 starting save to mongoDB
# 7start processing + 2010-09-01
# 7starting cluster , news news count:6455
# 750
# 265
# 45
# 9cluster end
# 9 starting save to mongoDB
# 9start processing + 2010-09-02
# 9starting cluster , news news count:5274
# 658
# 170
# 11cluster end
# 11 starting save to mongoDB
# 11start processing + 2010-09-03
# 11starting cluster , news news count:3572
# 464
# 21
# 46
# 12cluster end
# 12 starting save to mongoDB
# 12start processing + 2010-09-04
# 12starting cluster , news news count:2160
# 353
# 13cluster end
# 13 starting save to mongoDB
# restarting...
# 13start processing + 2010-09-05
# 14starting cluster , news news count:3257
# 477
# 86
# 14cluster end
# 14 starting save to mongoDB
# 14start processing + 2010-09-06
# 15starting cluster , news news count:4905
# 627
# 227
# 16cluster end
# 16 starting save to mongoDB
# 16start processing + 2010-09-07
# 16starting cluster , news news count:5659
# 660
# 259
# 18cluster end
# 18 starting save to mongoDB
# 18start processing + 2010-09-08
# 18starting cluster , news news count:6109
# 675
# 275
# 17
# 20cluster end
# 20 starting save to mongoDB
# 20start processing + 2010-09-09
# 20starting cluster , news news count:5138
# 642
# 194
# 22cluster end
# 22 starting save to mongoDB
# 22start processing + 2010-09-10
# 22starting cluster , news news count:3661
# 481
# 84
# 23cluster end
# 23 starting save to mongoDB
# 23start processing + 2010-09-11
# 24starting cluster , news news count:2110
# 335
# 24cluster end
# 24 starting save to mongoDB
# restarting...
# 24start processing + 2010-09-12
# 25starting cluster , news news count:3093
# 443
# 90
# 25cluster end
# 25 starting save to mongoDB
# 26start processing + 2010-09-13
# 26starting cluster , news news count:4604
# 597
# 184
# 27cluster end
# 27 starting save to mongoDB
# 27start processing + 2010-09-14
# 27starting cluster , news news count:5292
# 675
# 198
# 28cluster end
# 28 starting save to mongoDB
# 29start processing + 2010-09-15
# 29starting cluster , news news count:5659
# 696
# 12
# 13
# 194
# 30cluster end
# 30 starting save to mongoDB
# 30start processing + 2010-09-16
# 31starting cluster , news news count:4807
# 595
# 150
# 8
# 32cluster end
# 32 starting save to mongoDB
# 32start processing + 2010-09-17
# 32starting cluster , news news count:3541
# 442
# 76
# 7
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2010-09-18
# 34starting cluster , news news count:2155
# 313
# 42
# 34cluster end
# 34 starting save to mongoDB
# restarting...
# 35start processing + 2010-09-19
# 35starting cluster , news news count:3028
# 482
# 59
# 35cluster end
# 35 starting save to mongoDB
# 36start processing + 2010-09-20
# 36starting cluster , news news count:2988
# 472
# 64
# 37cluster end
# 37 starting save to mongoDB
# 37start processing + 2010-09-21
# 37starting cluster , news news count:2107
# 372
# 37cluster end
# 37 starting save to mongoDB
# 38start processing + 2010-09-22
# 38starting cluster , news news count:413
# 18
# 38cluster end
# 38 starting save to mongoDB
# 38start processing + 2010-09-23
# 38starting cluster , news news count:374
# 12
# 38cluster end
# 38 starting save to mongoDB
# 38start processing + 2010-09-24
# 39starting cluster , news news count:366
# 12
# 39cluster end
# 39 starting save to mongoDB
# 39start processing + 2010-09-25
# 39starting cluster , news news count:1182
# 202
# 39cluster end
# 39 starting save to mongoDB
# restarting...
# 40start processing + 2010-09-26
# 40starting cluster , news news count:2598
# 447
# 77
# 41cluster end
# 41 starting save to mongoDB
# 41start processing + 2010-09-27
# 41starting cluster , news news count:4111
# 630
# 197
# 42cluster end
# 42 starting save to mongoDB
# 42start processing + 2010-09-28
# 43starting cluster , news news count:5139
# 737
# 233
# 44cluster end
# 44 starting save to mongoDB
# 44start processing + 2010-09-29
# 44starting cluster , news news count:4128
# 629
# 165
# 45cluster end
# 45 starting save to mongoDB
# 46start processing + 2010-09-30
# 46starting cluster , news news count:2756
# 444
# 47
# 46cluster end
# 46 starting save to mongoDB
# 47start processing + 2010-10-01
# 47starting cluster , news news count:454
# 28
# 47cluster end
# 47 starting save to mongoDB
# 47start processing + 2010-10-02
# 47starting cluster , news news count:412
# 24
# 47cluster end
# 47 starting save to mongoDB
# restarting...
# 48start processing + 2010-10-03
# 48starting cluster , news news count:505
# 51
# 48cluster end
# 48 starting save to mongoDB
# 48start processing + 2010-10-04
# 48starting cluster , news news count:617
# 58
# 48cluster end
# 48 starting save to mongoDB
# 49start processing + 2010-10-05
# 49starting cluster , news news count:646
# 70
# 49cluster end
# 49 starting save to mongoDB
# 49start processing + 2010-10-06
# 49starting cluster , news news count:1438
# 236
# 50cluster end
# 50 starting save to mongoDB
# 50start processing + 2010-10-07
# 50starting cluster , news news count:1484
# 242
# 50cluster end
# 50 starting save to mongoDB
# 50start processing + 2010-10-08
# 51starting cluster , news news count:1423
# 238
# 51cluster end
# 51 starting save to mongoDB
# 51start processing + 2010-10-09
# 51starting cluster , news news count:1686
# 282
# 52cluster end
# 52 starting save to mongoDB
# restarting...
# 52start processing + 2010-10-10
# 52starting cluster , news news count:3132
# 529
# 97
# 53cluster end
# 53 starting save to mongoDB
# 53start processing + 2010-10-11
# 53starting cluster , news news count:4755
# 648
# 236
# 54cluster end
# 54 starting save to mongoDB
# 55start processing + 2010-10-12
# 55starting cluster , news news count:5590
# 712
# 299
# 56cluster end
# 56 starting save to mongoDB
# 57start processing + 2010-10-13
# 57starting cluster , news news count:5803
# 715
# 296
# 58cluster end
# 58 starting save to mongoDB
# 59start processing + 2010-10-14
# 59starting cluster , news news count:4814
# 625
# 185
# 0cluster end
# 0 starting save to mongoDB
# 0start processing + 2010-10-15
# 1starting cluster , news news count:3289
# 450
# 64
# 1cluster end
# 1 starting save to mongoDB
# 2start processing + 2010-10-16
# 2starting cluster , news news count:2069
# 366
# 2cluster end
# 2 starting save to mongoDB
# restarting...
# 3start processing + 2010-10-17
# 3starting cluster , news news count:3283
# 538
# 131
# 3cluster end
# 3 starting save to mongoDB
# 4start processing + 2010-10-18
# 4starting cluster , news news count:4799
# 688
# 220
# 37
# 5cluster end
# 5 starting save to mongoDB
# 5start processing + 2010-10-19
# 6starting cluster , news news count:5356
# 699
# 262
# 7cluster end
# 7 starting save to mongoDB
# 7start processing + 2010-10-20
# 7starting cluster , news news count:5899
# 685
# 281
# 46
# 9cluster end
# 9 starting save to mongoDB
# 9start processing + 2010-10-21
# 10starting cluster , news news count:4915
# 617
# 174
# 11cluster end
# 11 starting save to mongoDB
# 11start processing + 2010-10-22
# 11starting cluster , news news count:3616
# 503
# 54
# 12cluster end
# 12 starting save to mongoDB
# 13start processing + 2010-10-23
# 13starting cluster , news news count:2254
# 381
# 41
# 13cluster end
# 13 starting save to mongoDB
# restarting...
# 14start processing + 2010-10-24
# 14starting cluster , news news count:3500
# 495
# 102
# 15cluster end
# 15 starting save to mongoDB
# 15start processing + 2010-10-25
# 15starting cluster , news news count:5169
# 662
# 252
# 16cluster end
# 16 starting save to mongoDB
# 17start processing + 2010-10-26
# 17starting cluster , news news count:6065
# 747
# 277
# 61
# 18cluster end
# 18 starting save to mongoDB
# 19start processing + 2010-10-27
# 19starting cluster , news news count:6578
# 763
# 320
# 65
# 20cluster end
# 20 starting save to mongoDB
# 21start processing + 2010-10-28
# 21starting cluster , news news count:5563
# 640
# 237
# 22cluster end
# 22 starting save to mongoDB
# 22start processing + 2010-10-29
# 23starting cluster , news news count:3953
# 470
# 127
# 24cluster end
# 24 starting save to mongoDB
# 24start processing + 2010-10-30
# 24starting cluster , news news count:2238
# 350
# 24cluster end
# 24 starting save to mongoDB
# restarting...
# 25start processing + 2010-10-31
# 25starting cluster , news news count:3233
# 480
# 129
# 26cluster end
# 26 starting save to mongoDB
# 26start processing + 2010-11-01
# 26starting cluster , news news count:4682
# 659
# 231
# 27cluster end
# 27 starting save to mongoDB
# 28start processing + 2010-11-02
# 28starting cluster , news news count:5206
# 689
# 225
# 29cluster end
# 29 starting save to mongoDB
# 29start processing + 2010-11-03
# 30starting cluster , news news count:5497
# 696
# 199
# 14
# 31cluster end
# 31 starting save to mongoDB
# 31start processing + 2010-11-04
# 32starting cluster , news news count:4586
# 602
# 130
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2010-11-05
# 33starting cluster , news news count:3290
# 424
# 57
# 34cluster end
# 34 starting save to mongoDB
# 34start processing + 2010-11-06
# 35starting cluster , news news count:2024
# 336
# 35cluster end
# 35 starting save to mongoDB
# restarting...
# 35start processing + 2010-11-07
# 36starting cluster , news news count:3079
# 468
# 95
# 36cluster end
# 36 starting save to mongoDB
# 38start processing + 2010-11-08
# 38starting cluster , news news count:4572
# 619
# 200
# 39cluster end
# 39 starting save to mongoDB
# 39start processing + 2010-11-09
# 40starting cluster , news news count:5405
# 692
# 226
# 41cluster end
# 41 starting save to mongoDB
# 41start processing + 2010-11-10
# 41starting cluster , news news count:5805
# 694
# 246
# 77
# 43cluster end
# 43 starting save to mongoDB
# 43start processing + 2010-11-11
# 43starting cluster , news news count:4810
# 619
# 174
# 44
# 45cluster end
# 45 starting save to mongoDB
# 45start processing + 2010-11-12
# 45starting cluster , news news count:3424
# 438
# 80
# 18
# 46cluster end
# 46 starting save to mongoDB
# 46start processing + 2010-11-13
# 46starting cluster , news news count:1980
# 317
# 47cluster end
# 47 starting save to mongoDB
# restarting...
# 47start processing + 2010-11-14
# 47starting cluster , news news count:3106
# 481
# 65
# 48cluster end
# 48 starting save to mongoDB
# 48start processing + 2010-11-15
# 49starting cluster , news news count:4649
# 663
# 168
# 29
# 49cluster end
# 49 starting save to mongoDB
# 50start processing + 2010-11-16
# 50starting cluster , news news count:5334
# 718
# 185
# 30
# 51cluster end
# 51 starting save to mongoDB
# 51start processing + 2010-11-17
# 52starting cluster , news news count:5575
# 722
# 217
# 7
# 53cluster end
# 53 starting save to mongoDB
# 53start processing + 2010-11-18
# 54starting cluster , news news count:4623
# 641
# 151
# 55cluster end
# 55 starting save to mongoDB
# 55start processing + 2010-11-19
# 55starting cluster , news news count:3305
# 440
# 58
# 56cluster end
# 56 starting save to mongoDB
# 56start processing + 2010-11-20
# 56starting cluster , news news count:1954
# 310
# 57cluster end
# 57 starting save to mongoDB
# restarting...
# 58start processing + 2010-11-21
# 58starting cluster , news news count:3063
# 466
# 101
# 58cluster end
# 58 starting save to mongoDB
# 59start processing + 2010-11-22
# 59starting cluster , news news count:4550
# 647
# 193
# 0cluster end
# 0 starting save to mongoDB
# 0start processing + 2010-11-23
# 0starting cluster , news news count:5186
# 714
# 239
# 1cluster end
# 1 starting save to mongoDB
# 2start processing + 2010-11-24
# 2starting cluster , news news count:5440
# 707
# 245
# 3cluster end
# 3 starting save to mongoDB
# 4start processing + 2010-11-25
# 4starting cluster , news news count:4510
# 604
# 164
# 5cluster end
# 5 starting save to mongoDB
# 5start processing + 2010-11-26
# 5starting cluster , news news count:3265
# 441
# 78
# 6cluster end
# 6 starting save to mongoDB
# 6start processing + 2010-11-27
# 7starting cluster , news news count:2025
# 340
# 7cluster end
# 7 starting save to mongoDB
# restarting...
# 7start processing + 2010-11-28
# 8starting cluster , news news count:3283
# 515
# 86
# 8cluster end
# 8 starting save to mongoDB
# 9start processing + 2010-11-29
# 9starting cluster , news news count:4823
# 685
# 179
# 10cluster end
# 10 starting save to mongoDB
# 10start processing + 2010-11-30
# 10starting cluster , news news count:5505
# 751
# 225
# 12cluster end
# 12 starting save to mongoDB
# 12start processing + 2010-12-01
# 12starting cluster , news news count:5822
# 743
# 242
# 14cluster end
# 14 starting save to mongoDB
# 14start processing + 2010-12-02
# 14starting cluster , news news count:4999
# 665
# 189
# 15cluster end
# 15 starting save to mongoDB
# 16start processing + 2010-12-03
# 16starting cluster , news news count:3579
# 474
# 36
# 17cluster end
# 17 starting save to mongoDB
# 17start processing + 2010-12-04
# 17starting cluster , news news count:2101
# 361
# 18cluster end
# 18 starting save to mongoDB
# restarting...
# 18start processing + 2010-12-05
# 18starting cluster , news news count:3044
# 518
# 92
# 19cluster end
# 19 starting save to mongoDB
# 19start processing + 2010-12-06
# 20starting cluster , news news count:4501
# 695
# 185
# 21cluster end
# 21 starting save to mongoDB
# 23start processing + 2010-12-07
# 23starting cluster , news news count:5061
# 731
# 195
# 24cluster end
# 24 starting save to mongoDB
# 24start processing + 2010-12-08
# 25starting cluster , news news count:5335
# 700
# 247
# 26cluster end
# 26 starting save to mongoDB
# 26start processing + 2010-12-09
# 27starting cluster , news news count:4538
# 614
# 146
# 28cluster end
# 28 starting save to mongoDB
# 28start processing + 2010-12-10
# 28starting cluster , news news count:3131
# 451
# 29cluster end
# 29 starting save to mongoDB
# 29start processing + 2010-12-11
# 29starting cluster , news news count:2090
# 357
# 30cluster end
# 30 starting save to mongoDB
# restarting...
# 30start processing + 2010-12-12
# 30starting cluster , news news count:3099
# 496
# 78
# 31cluster end
# 31 starting save to mongoDB
# 31start processing + 2010-12-13
# 32starting cluster , news news count:4664
# 693
# 188
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2010-12-14
# 33starting cluster , news news count:5278
# 730
# 216
# 35cluster end
# 35 starting save to mongoDB
# 35start processing + 2010-12-15
# 35starting cluster , news news count:5564
# 691
# 229
# 36cluster end
# 36 starting save to mongoDB
# 37start processing + 2010-12-16
# 37starting cluster , news news count:4624
# 593
# 144
# 38cluster end
# 38 starting save to mongoDB
# 38start processing + 2010-12-17
# 39starting cluster , news news count:3228
# 456
# 51
# 39cluster end
# 39 starting save to mongoDB
# 40start processing + 2010-12-18
# 40starting cluster , news news count:1909
# 328
# 40cluster end
# 40 starting save to mongoDB
# restarting...
# 41start processing + 2010-12-19
# 41starting cluster , news news count:2983
# 534
# 58
# 42cluster end
# 42 starting save to mongoDB
# 42start processing + 2010-12-20
# 42starting cluster , news news count:4420
# 720
# 153
# 43cluster end
# 43 starting save to mongoDB
# 43start processing + 2010-12-21
# 44starting cluster , news news count:5091
# 770
# 182
# 45cluster end
# 45 starting save to mongoDB
# 45start processing + 2010-12-22
# 45starting cluster , news news count:5372
# 775
# 204
# 18
# 47cluster end
# 47 starting save to mongoDB
# 47start processing + 2010-12-23
# 47starting cluster , news news count:4418
# 634
# 113
# 15
# 48cluster end
# 48 starting save to mongoDB
# 49start processing + 2010-12-24
# 49starting cluster , news news count:3107
# 463
# 51
# 50cluster end
# 50 starting save to mongoDB
# 50start processing + 2010-12-25
# 50starting cluster , news news count:1791
# 276
# 51cluster end
# 51 starting save to mongoDB
# restarting...
# 51start processing + 2010-12-26
# 51starting cluster , news news count:2787
# 428
# 78
# 52cluster end
# 52 starting save to mongoDB
# 52start processing + 2010-12-27
# 52starting cluster , news news count:4160
# 622
# 157
# 53cluster end
# 53 starting save to mongoDB
# 54start processing + 2010-12-28
# 54starting cluster , news news count:4898
# 718
# 189
# 55cluster end
# 55 starting save to mongoDB
# 55start processing + 2010-12-29
# 55starting cluster , news news count:5321
# 787
# 186
# 24
# 57cluster end
# 57 starting save to mongoDB
# 57start processing + 2010-12-30
# 57starting cluster , news news count:4200
# 648
# 97
# 58cluster end
# 58 starting save to mongoDB
# 59start processing + 2010-12-31
# 59starting cluster , news news count:2876
# 425
# 35
# 0cluster end
# 0 starting save to mongoDB
# 0start processing + 2011-01-01
# 0starting cluster , news news count:564
# 43
# 0cluster end
# 0 starting save to mongoDB
# restarting...
# 0start processing + 2011-01-02
# 1starting cluster , news news count:1282
# 243
# 1cluster end
# 1 starting save to mongoDB
# 1start processing + 2011-01-03
# 1starting cluster , news news count:2588
# 515
# 2cluster end
# 2 starting save to mongoDB
# 2start processing + 2011-01-04
# 2starting cluster , news news count:3955
# 725
# 74
# 3cluster end
# 3 starting save to mongoDB
# 4start processing + 2011-01-05
# 4starting cluster , news news count:4831
# 792
# 100
# 5cluster end
# 5 starting save to mongoDB
# 5start processing + 2011-01-06
# 5starting cluster , news news count:4104
# 700
# 6cluster end
# 6 starting save to mongoDB
# 7start processing + 2011-01-07
# 7starting cluster , news news count:2959
# 484
# 7cluster end
# 7 starting save to mongoDB
# 8start processing + 2011-01-08
# 8starting cluster , news news count:1848
# 290
# 8cluster end
# 8 starting save to mongoDB
# restarting...
# 9start processing + 2011-01-09
# 9starting cluster , news news count:2922
# 471
# 67
# 10cluster end
# 10 starting save to mongoDB
# 10start processing + 2011-01-10
# 10starting cluster , news news count:4375
# 648
# 134
# 11cluster end
# 11 starting save to mongoDB
# 11start processing + 2011-01-11
# 12starting cluster , news news count:5048
# 735
# 178
# 13cluster end
# 13 starting save to mongoDB
# 13start processing + 2011-01-12
# 13starting cluster , news news count:5282
# 745
# 193
# 14cluster end
# 14 starting save to mongoDB
# 15start processing + 2011-01-13
# 15starting cluster , news news count:4329
# 657
# 118
# 16cluster end
# 16 starting save to mongoDB
# 16start processing + 2011-01-14
# 16starting cluster , news news count:2924
# 444
# 51
# 17cluster end
# 17 starting save to mongoDB
# 17start processing + 2011-01-15
# 18starting cluster , news news count:1936
# 328
# 18cluster end
# 18 starting save to mongoDB
# restarting...
# 18start processing + 2011-01-16
# 19starting cluster , news news count:3081
# 480
# 98
# 19cluster end
# 19 starting save to mongoDB
# 19start processing + 2011-01-17
# 20starting cluster , news news count:4571
# 636
# 186
# 21cluster end
# 21 starting save to mongoDB
# 21start processing + 2011-01-18
# 21starting cluster , news news count:5287
# 691
# 210
# 22cluster end
# ...
# 43starting cluster , news news count:7660
# 830
# 392
# 204
# 35
# 25
# 13
# 44cluster end
# 44 starting save to mongoDB
# 44start processing + 2012-11-05
# 45starting cluster , news news count:11134
# 1077
# 569
# 401
# 93
# 46
# 15
# 1
# 1
# 0
# 48cluster end
# 48 starting save to mongoDB
# 48start processing + 2012-11-06
# 48starting cluster , news news count:11800
# 1051
# 596
# 418
# 137
# 69
# 50cluster end
# 50 starting save to mongoDB
# 50start processing + 2012-11-07
# 51starting cluster , news news count:12565
# 1055
# 611
# 440
# 151
# 68
# 54cluster end
# 54 starting save to mongoDB
# 54start processing + 2012-11-08
# 55starting cluster , news news count:9912
# 876
# 444
# 301
# 86
# 49
# 56cluster end
# 56 starting save to mongoDB
# 56start processing + 2012-11-09
# 57starting cluster , news news count:6985
# 628
# 290
# 146
# 46
# 33
# 58cluster end
# 58 starting save to mongoDB
# 59start processing + 2012-11-10
# 59starting cluster , news news count:5026
# 594
# 178
# 86
# 34
# 23
# 21
# 0cluster end
# 0 starting save to mongoDB
# restarting...
# 0start processing + 2012-11-11
# 1starting cluster , news news count:7541
# 815
# 340
# 182
# 62
# 22
# 2cluster end
# 2 starting save to mongoDB
# 3start processing + 2012-11-12
# 3starting cluster , news news count:10920
# 1048
# 552
# 348
# 114
# 44
# 11
# 5cluster end
# 5 starting save to mongoDB
# 5start processing + 2012-11-13
# 6starting cluster , news news count:12239
# 1038
# 633
# 415
# 129
# 50
# 12
# 8cluster end
# 8 starting save to mongoDB
# 9start processing + 2012-11-14
# 9starting cluster , news news count:12906
# 1030
# 667
# 438
# 119
# 49
# 14
# 1
# 1
# 0
# 12cluster end
# 12 starting save to mongoDB
# 12start processing + 2012-11-15
# 13starting cluster , news news count:10074
# 895
# 494
# 302
# 87
# 37
# 15cluster end
# 15 starting save to mongoDB
# 15start processing + 2012-11-16
# 16starting cluster , news news count:7003
# 708
# 291
# 115
# 47
# 25
# 17cluster end
# 17 starting save to mongoDB
# 17start processing + 2012-11-17
# 17starting cluster , news news count:5085
# 603
# 185
# 85
# 36
# 14
# 18cluster end
# 18 starting save to mongoDB
# restarting...
# 19start processing + 2012-11-18
# 19starting cluster , news news count:7880
# 838
# 341
# 188
# 83
# 22
# 20cluster end
# 20 starting save to mongoDB
# 21start processing + 2012-11-19
# 21starting cluster , news news count:11620
# 1025
# 572
# 327
# 137
# 54
# 14
# 24cluster end
# 24 starting save to mongoDB
# 24start processing + 2012-11-20
# 25starting cluster , news news count:12610
# 1071
# 583
# 342
# 177
# 54
# 10
# 27cluster end
# 27 starting save to mongoDB
# 27start processing + 2012-11-21
# 28starting cluster , news news count:12868
# 1069
# 579
# 329
# 124
# 59
# 10
# 31cluster end
# 31 starting save to mongoDB
# 31start processing + 2012-11-22
# 32starting cluster , news news count:9998
# 934
# 386
# 221
# 71
# 46
# 10
# 33cluster end
# 33 starting save to mongoDB
# 33start processing + 2012-11-23
# 34starting cluster , news news count:6826
# 677
# 204
# 87
# 39
# 34
# 10
# 35cluster end
# 35 starting save to mongoDB
# 36start processing + 2012-11-24
# 36starting cluster , news news count:4854
# 600
# 160
# 45
# 22
# 17
# 37cluster end
# 37 starting save to mongoDB
# restarting...
# 37start processing + 2012-11-25
# 37starting cluster , news news count:7469
# 799
# 316
# 77
# 56
# 34
# 60
# 39cluster end
# 39 starting save to mongoDB
# 39start processing + 2012-11-26
# 40starting cluster , news news count:10599
# 1018
# 522
# 241
# 95
# 50
# 6
# 42cluster end
# 42 starting save to mongoDB
# 42start processing + 2012-11-27
# 42starting cluster , news news count:11662
# 961
# 554
# 323
# 118
# 65
# 11
# 1
# 1
# 0
# 45cluster end
# 45 starting save to mongoDB
# 46start processing + 2012-11-28
# 46starting cluster , news news count:11697
# 1015
# 577
# 315
# 127
# 54
# 48cluster end
# 48 starting save to mongoDB
# 48start processing + 2012-11-29
# 49starting cluster , news news count:9651
# 885
# 431
# 249
# 80
# 46
# 51cluster end
# 51 starting save to mongoDB
# 51start processing + 2012-11-30
# 52starting cluster , news news count:7022
# 719
# 227
# 127
# 52
# 26
# 53cluster end
# 53 starting save to mongoDB
# 53start processing + 2012-12-01
# 53starting cluster , news news count:4999
# 557
# 156
# 83
# 32
# 14
# 54cluster end
# 54 starting save to mongoDB
# restarting...
# 55start processing + 2012-12-02
# 55starting cluster , news news count:7306
# 857
# 284
# 180
# 64
# 24
# 17
# 56cluster end
# 56 starting save to mongoDB
# 57start processing + 2012-12-03
# 57starting cluster , news news count:10311
# 1078
# 497
# 253
# 119
# 44
# 18
# 59cluster end
# 59 starting save to mongoDB
# 0start processing + 2012-12-04
# 0starting cluster , news news count:11586
# 1115
# 556
# 297
# 115
# 53
# 21
# 2cluster end
# 2 starting save to mongoDB
# 2start processing + 2012-12-05
# 3starting cluster , news news count:12155
# 1092
# 612
# 322
# 138
# 43
# 20
# 6cluster end
# 6 starting save to mongoDB
# 6start processing + 2012-12-06
# 7starting cluster , news news count:9967
# 931
# 429
# 237
# 95
# 20
# 16
# 8cluster end
# 8 starting save to mongoDB
# 9start processing + 2012-12-07
# 9starting cluster , news news count:7218
# 769
# 212
# 110
# 34
# 12
# 11
# 11cluster end
# 11 starting save to mongoDB
# 11start processing + 2012-12-08
# 12starting cluster , news news count:5022
# 558
# 188
# 55
# 18
# 17
# 10
# 12cluster end
# 12 starting save to mongoDB
# restarting...
# 13start processing + 2012-12-09
# 13starting cluster , news news count:7550
# 792
# 312
# 155
# 34
# 27
# 9
# 1
# 1
# 0
# 15cluster end
# 15 starting save to mongoDB
# 15start processing + 2012-12-10
# 16starting cluster , news news count:10179
# 1009
# 517
# 286
# 59
# 43
# 17cluster end
# 17 starting save to mongoDB
# 17start processing + 2012-12-11
# 18starting cluster , news news count:11531
# 997
# 610
# 319
# 22
# 97
# 50
# 22
# 20cluster end
# 20 starting save to mongoDB
# 21start processing + 2012-12-12
# 21starting cluster , news news count:12202
# 1027
# 639
# 307
# 27
# 115
# 60
# 23cluster end
# 23 starting save to mongoDB
# 23start processing + 2012-12-13
# 24starting cluster , news news count:9741
# 884
# 447
# 213
# 27
# 84
# 43
# 26cluster end
# 26 starting save to mongoDB
# 27start processing + 2012-12-14
# 27starting cluster , news news count:6883
# 696
# 253
# 114
# 18
# 43
# 31
# 28cluster end
# 28 starting save to mongoDB
# 28start processing + 2012-12-15
# 29starting cluster , news news count:4310
# 542
# 130
# 57
# 24
# 11
# 29cluster end
# 29 starting save to mongoDB
# restarting...
# 30start processing + 2012-12-16
# 30starting cluster , news news count:6824
# 755
# 323
# 136
# 54
# 24
# 11
# 31cluster end
# 31 starting save to mongoDB
# 32start processing + 2012-12-17
# 32starting cluster , news news count:10075
# 1000
# 497
# 222
# 104
# 35
# 20
# 34cluster end
# 34 starting save to mongoDB
# 35start processing + 2012-12-18
# 35starting cluster , news news count:11505
# 1060
# 526
# 310
# 116
# 33
# 20
# 37cluster end
# 37 starting save to mongoDB
# 37start processing + 2012-12-19
# 38starting cluster , news news count:12117
# 1040
# 547
# 360
# 120
# 47
# 27
# 41cluster end
# 41 starting save to mongoDB
# 41start processing + 2012-12-20
# 42starting cluster , news news count:9948
# 921
# 429
# 267
# 79
# 34
# 24
# 43cluster end
# 43 starting save to mongoDB
# 44start processing + 2012-12-21
# 44starting cluster , news news count:6903
# 703
# 209
# 110
# 42
# 27
# 15
# 29
# 46cluster end
# 46 starting save to mongoDB
# 46start processing + 2012-12-22
# 46starting cluster , news news count:4408
# 599
# 124
# 45
# 4
# 5
# 3
# 1
# 1
# 0
# 47cluster end
# 47 starting save to mongoDB
# restarting...
# 47start processing + 2012-12-23
# 48starting cluster , news news count:5542
# 733
# 224
# 105
# 49cluster end
# 49 starting save to mongoDB
# 49start processing + 2012-12-24
# 49starting cluster , news news count:7723
# 915
# 357
# 183
# 50cluster end
# 50 starting save to mongoDB
# 51start processing + 2012-12-25
# 51starting cluster , news news count:8432
# 893
# 407
# 210
# 58
# 53cluster end
# 53 starting save to mongoDB
# 53start processing + 2012-12-26
# 54starting cluster , news news count:9751
# 996
# 481
# 281
# 92
# 38
# 55cluster end
# 55 starting save to mongoDB
# 55start processing + 2012-12-27
# 56starting cluster , news news count:8325
# 916
# 360
# 223
# 70
# 30
# 57cluster end
# 57 starting save to mongoDB
# 58start processing + 2012-12-28
# 58starting cluster , news news count:6167
# 734
# 211
# 146
# 42
# 23
# 59cluster end
# 59 starting save to mongoDB
# 59start processing + 2012-12-29
# 59starting cluster , news news count:3426
# 511
# 84
# 38
# 0cluster end
# 0 starting save to mongoDB
# restarting...
# 0start processing + 2012-12-30
# 1starting cluster , news news count:2424
# 413
# 55
# 25
# 1cluster end
# 1 starting save to mongoDB
# 3start processing + 2012-12-31
# 3starting cluster , news news count:2242
# 382
# 50
# 4cluster end
# 4 starting save to mongoDB
# 4start processing + 2013-01-01
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# --args is deprecated. Use --arg instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-b9ca858a92d1> in <module>()
# ----> 1 main__()
#
# <ipython-input-61-12f2e20c8fee> in main__()
#      12     #batch
#      13     processDayFirst7(datetime(2010,1,1))
# ---> 14     processDayAcc(datetime(2010,1,2), datetime(2014,9,26))
#      15     #restoreFromError(datetime(2013,11,17),datetime(2014,9,11))
#
# <ipython-input-57-5718f5a83933> in processDayAcc(stDate, edDate)
#      14         pirNews = getNews(stDateStr,edDateStr)
#      15         pirNews = pirNews.union(tempRDD)
# ---> 16         groupedAllRDD = processPriodNews(pirNews)
#      17         nextDate = curDate + timedelta(1)
#      18         nextDateStr = nextDate.strftime('%Y-%m-%d')
#
# <ipython-input-54-d3c614829cf1> in processPriodNews(pirNews)
#       9     finalData = dataGroupped.flatMap(lambda (x,y):agg(x,y)).reduceByKey(lambda x,y:x+y)
#      10     #get parse matrix
# ---> 11     cosineDist = triple2ParseMatrix(finalData)
#      12     distDok =cosineDist.todok().keys()
#      13     #partition
#
# <ipython-input-52-1f6ba4a73c8d> in triple2ParseMatrix(finalData)
#       4     DistI = [int(x) for ((x,y),z) in DistTriple]
#       5     DistJ = [int(y) for ((x,y),z) in DistTriple]
# ----> 6     maxInd = max(DistI+DistJ)
#       7     DistV = [z for ((x,y),z) in DistTriple]
#       8     Dist = coo_matrix((DistV,(DistI,DistJ)),shape=(maxInd+1,maxInd+1))
#
# ValueError: max() arg is an empty sequence

# %%
sc.stop()
